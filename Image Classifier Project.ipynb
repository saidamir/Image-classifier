# %% [markdown]
# # Developing an AI application
#
# Going forward, AI algorithms will be incorporated into more and more everyday applications. For example, you might want to include an image classifier in a smart phone app. To do this, you'd use a deep learning model trained on hundreds of thousands of images as part of the overall application architecture. A large part of software development in the future will be using these types of models as common parts of applications.
#
# In this project, you'll train an image classifier to recognize different species of flowers. You can imagine using something like this in a phone app that tells you the name of the flower your camera is looking at. In practice you'd train this classifier, then export it for use in your application. We'll be using [this dataset](http://www.robots.ox.ac.uk/~vgg/data/flowers/102/index.html) of 102 flower categories, you can see a few examples below.
#
# <img src='assets/Flowers.png' width=500px>
#
# The project is broken down into multiple steps:
#
# * Load and preprocess the image dataset
# * Train the image classifier on your dataset
# * Use the trained classifier to predict image content
#
# We'll lead you through each part which you'll implement in Python.
#
# When you've completed this project, you'll have an application that can be trained on any set of labeled images. Here your network will be learning about flowers and end up as a command line application. But, what you do with your new skills depends on your imagination and effort in building a dataset. For example, imagine an app where you take a picture of a car, it tells you what the make and model is, then looks up information about it. Go build your own dataset and make something new.
#
# First up is importing the packages you'll need. It's good practice to keep all the imports at the beginning of your code. As you work through this notebook and find you need to import a package, make sure to add the import up here.

# %%
# Imports here
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt

import torch
import numpy as np
from torch import nn
from torch import optim
import torch.nn.functional as F
from torchvision import datasets, transforms, models

from PIL import Image
import time
import json
from collections import OrderedDict

# %% [markdown]
# ## Load the data
#
# Here you'll use `torchvision` to load the data ([documentation](http://pytorch.org/docs/0.3.0/torchvision/index.html)). The data should be included alongside this notebook, otherwise you can [download it here](https://s3.amazonaws.com/content.udacity-data.com/nd089/flower_data.tar.gz). The dataset is split into three parts, training, validation, and testing. For the training, you'll want to apply transformations such as random scaling, cropping, and flipping. This will help the network generalize leading to better performance. You'll also need to make sure the input data is resized to 224x224 pixels as required by the pre-trained networks.
#
# The validation and testing sets are used to measure the model's performance on data it hasn't seen yet. For this you don't want any scaling or rotation transformations, but you'll need to resize then crop the images to the appropriate size.
#
# The pre-trained networks you'll use were trained on the ImageNet dataset where each color channel was normalized separately. For all three sets you'll need to normalize the means and standard deviations of the images to what the network expects. For the means, it's `[0.485, 0.456, 0.406]` and for the standard deviations `[0.229, 0.224, 0.225]`, calculated from the ImageNet images.  These values will shift each color channel to be centered at 0 and range from -1 to 1.

# %%
data_dir = 'flowers'
train_dir = data_dir + '/train'
valid_dir = data_dir + '/valid'
test_dir = data_dir + '/test'

# %%
# TODO: Define your transforms for the training, validation, and testing sets
train_transforms = transforms.Compose([transforms.RandomRotation(30),
                                       transforms.RandomResizedCrop(224),
                                       transforms.RandomHorizontalFlip(),
                                       transforms.ToTensor(),
                                       transforms.Normalize([0.485, 0.456, 0.406], 
                                                            [0.229, 0.224, 0.225])])

# TODO: Load the datasets with ImageFolder
test_transforms =transforms.Compose([transforms.Resize(256),
                                      transforms.CenterCrop(224),
                                      transforms.ToTensor(),
                                      transforms.Normalize([0.485, 0.456, 0.406], 
                                                           [0.229, 0.224, 0.225])]) 

# TODO: Using the image datasets and the trainforms, define the dataloaders
train_data = datasets.ImageFolder(train_dir, transform=train_transforms)
test_data = datasets.ImageFolder(test_dir, transform=test_transforms)
validation_data = datasets.ImageFolder(valid_dir, transform=test_transforms)

trainloader = torch.utils.data.DataLoader(train_data, batch_size=64, shuffle=True)
testloader = torch.utils.data.DataLoader(test_data, batch_size=32)
validloader = torch.utils.data.DataLoader(validation_data, batch_size=32)

# %%
steps = 0
for x,y in trainloader:
    steps +=1
    if steps<2:
        print (x.shape,y.shape)
# Out:
# torch.Size([64, 3, 224, 224]) torch.Size([64])

# %% [markdown]
# ### Label mapping
#
# You'll also need to load in a mapping from category label to category name. You can find this in the file `cat_to_name.json`. It's a JSON object which you can read in with the [`json` module](https://docs.python.org/2/library/json.html). This will give you a dictionary mapping the integer encoded categories to the actual names of the flowers.

# %%
import json

with open('cat_to_name.json', 'r') as f:
    cat_to_name = json.load(f)

# %%
print (cat_to_name)
# Out:
# {'21': 'fire lily', '3': 'canterbury bells', '45': 'bolero deep blue', '1': 'pink primrose', '34': 'mexican aster', '27': 'prince of wales feathers', '7': 'moon orchid', '16': 'globe-flower', '25': 'grape hyacinth', '26': 'corn poppy', '79': 'toad lily', '39': 'siam tulip', '24': 'red ginger', '67': 'spring crocus', '35': 'alpine sea holly', '32': 'garden phlox', '10': 'globe thistle', '6': 'tiger lily', '93': 'ball moss', '33': 'love in the mist', '9': 'monkshood', '102': 'blackberry lily', '14': 'spear thistle', '19': 'balloon flower', '100': 'blanket flower', '13': 'king protea', '49': 'oxeye daisy', '15': 'yellow iris', '61': 'cautleya spicata', '31': 'carnation', '64': 'silverbush', '68': 'bearded iris', '63': 'black-eyed susan', '69': 'windflower', '62': 'japanese anemone', '20': 'giant white arum lily', '38': 'great masterwort', '4': 'sweet pea', '86': 'tree mallow', '101': 'trumpet creeper', '42': 'daffodil', '22': 'pincushion flower', '2': 'hard-leaved pocket orchid', '54': 'sunflower', '66': 'osteospermum', '70': 'tree poppy', '85': 'desert-rose', '99': 'bromelia', '87': 'magnolia', '5': 'english marigold', '92': 'bee balm', '28': 'stemless gentian', '97': 'mallow', '57': 'gaura', '40': 'lenten rose', '47': 'marigold', '59': 'orange dahlia', '48': 'buttercup', '55': 'pelargonium', '36': 'ruby-lipped cattleya', '91': 'hippeastrum', '29': 'artichoke', '71': 'gazania', '90': 'canna lily', '18': 'peruvian lily', '98': 'mexican petunia', '8': 'bird of paradise', '30': 'sweet william', '17': 'purple coneflower', '52': 'wild pansy', '84': 'columbine', '12': "colt's foot", '11': 'snapdragon', '96': 'camellia', '23': 'fritillary', '50': 'common dandelion', '44': 'poinsettia', '53': 'primula', '72': 'azalea', '65': 'californian poppy', '80': 'anthurium', '76': 'morning glory', '37': 'cape flower', '56': 'bishop of llandaff', '60': 'pink-yellow dahlia', '82': 'clematis', '58': 'geranium', '75': 'thorn apple', '41': 'barbeton daisy', '95': 'bougainvillea', '43': 'sword lily', '83': 'hibiscus', '78': 'lotus lotus', '88': 'cyclamen', '94': 'foxglove', '81': 'frangipani', '74': 'rose', '89': 'watercress', '73': 'water lily', '46': 'wallflower', '77': 'passion flower', '51': 'petunia'}

# %% [markdown]
# # Building and training the classifier
#
# Now that the data is ready, it's time to build and train the classifier. As usual, you should use one of the pretrained models from `torchvision.models` to get the image features. Build and train a new feed-forward classifier using those features.
#
# We're going to leave this part up to you. Refer to [the rubric](https://review.udacity.com/#!/rubrics/1663/view) for guidance on successfully completing this section. Things you'll need to do:
#
# * Load a [pre-trained network](http://pytorch.org/docs/master/torchvision/models.html) (If you need a starting point, the VGG networks work great and are straightforward to use)
# * Define a new, untrained feed-forward network as a classifier, using ReLU activations and dropout
# * Train the classifier layers using backpropagation using the pre-trained network to get the features
# * Track the loss and accuracy on the validation set to determine the best hyperparameters
#
# We've left a cell open for you below, but use as many as you need. Our advice is to break the problem up into smaller parts you can run separately. Check that each part is doing what you expect, then move on to the next. You'll likely find that as you work through each part, you'll need to go back and modify your previous code. This is totally normal!
#
# When training make sure you're updating only the weights of the feed-forward network. You should be able to get the validation accuracy above 70% if you build everything right. Make sure to try different hyperparameters (learning rate, units in the classifier, epochs, etc) to find the best model. Save those hyperparameters to use as default values in the next part of the project.
#
# One last important tip if you're using the workspace to run your code: To avoid having your workspace disconnect during the long-running tasks in this notebook, please read in the earlier page in this lesson called Intro to
# GPU Workspaces about Keeping Your Session Active. You'll want to include code from the workspace_utils.py module.
#
# **Note for Workspace users:** If your network is over 1 GB when saved as a checkpoint, there might be issues with saving backups in your workspace. Typically this happens with wide dense layers after the convolutional layers. If your saved checkpoint is larger than 1 GB (you can open a terminal and check with `ls -lh`), you should reduce the size of your hidden layers and train again.

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
# TODO: Build and train your network
model = models.vgg16(pretrained=True)  
model
# Out:
# Downloading: "https://download.pytorch.org/models/vgg16-397923af.pth" to /root/.torch/models/vgg16-397923af.pth
# 100%|██████████| 553433881/553433881 [00:13<00:00, 41358607.14it/s]
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace)
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(inplace)
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU(inplace)
#     (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (27): ReLU(inplace)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace)
#     (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=4096, bias=True)
#     (1): ReLU(inplace)
#     (2): Dropout(p=0.5)
#     (3): Linear(in_features=4096, out_features=4096, bias=True)
#     (4): ReLU(inplace)
#     (5): Dropout(p=0.5)
#     (6): Linear(in_features=4096, out_features=1000, bias=True)
#   )
# )

# %%
for param in model.parameters():
        param.requires_grad = False
classifier = nn.Sequential(OrderedDict([
                          ('fc1', nn.Linear(25088, 600)),
                          ('relu', nn.ReLU()),
                          ('dropout1', nn.Dropout(0.05)),
                          ('fc2', nn.Linear(600, 102)),
                          ('output', nn.LogSoftmax(dim=1))
                          ]))
model.classifier = classifier

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
criterion = nn.NLLLoss()
optimizer = optim.Adam(model.classifier.parameters(), lr = 0.001 )
model.to(device);

# %%
epochs = 15
print_every = 5
steps = 0
loss_show=[]

# change to cuda
model.to(device)

for e in range(epochs):
    running_loss = 0
    for inputs, labels in trainloader:
        steps += 1
        
        inputs,labels = inputs.to(device), labels.to(device)
        
        optimizer.zero_grad()
        
        # Forward and backward passes
        outputs = model.forward(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        
        running_loss += loss.item()
        
        if steps % print_every == 0:
            model.eval()
            vlost = 0
            accuracy=0
            
            
            for inputs2,labels2 in validloader:
                optimizer.zero_grad()
                
                inputs2, labels2 = inputs2.to(device) , labels2.to(device)
                model.to(device)
                with torch.no_grad():    
                    outputs = model.forward(inputs2)
                    valid_lost = criterion(outputs,labels2)
                    ps = torch.exp(outputs).data
                    equality = (labels2.data == ps.max(1)[1])
                    accuracy += equality.type_as(torch.FloatTensor()).mean()
                    
            valid_lost = valid_lost / len(validloader)
            accuracy = accuracy /len(validloader)
            
                    
            
            print("Epoch: {}/{}... ".format(e+1, epochs),
                  "Train Loss: {:.3f}".format(running_loss/print_every),
                  "Validation Lost {:.3f}".format(valid_lost),
                   "Validation Accuracy: {:.3f}".format(accuracy))
            
            
            running_loss = 0
# Out:
# Epoch: 1/15...  Train Loss: 5.340 Validation Lost 0.184 Validation Accuracy: 0.141
# Epoch: 1/15...  Train Loss: 4.103 Validation Lost 0.188 Validation Accuracy: 0.266
# Epoch: 1/15...  Train Loss: 3.583 Validation Lost 0.150 Validation Accuracy: 0.323
# Epoch: 1/15...  Train Loss: 2.905 Validation Lost 0.166 Validation Accuracy: 0.424
# Epoch: 1/15...  Train Loss: 2.723 Validation Lost 0.107 Validation Accuracy: 0.517
# Epoch: 1/15...  Train Loss: 2.488 Validation Lost 0.056 Validation Accuracy: 0.577
# Epoch: 1/15...  Train Loss: 2.375 Validation Lost 0.054 Validation Accuracy: 0.610
# Epoch: 1/15...  Train Loss: 1.835 Validation Lost 0.039 Validation Accuracy: 0.677
# Epoch: 1/15...  Train Loss: 1.727 Validation Lost 0.034 Validation Accuracy: 0.720
# Epoch: 1/15...  Train Loss: 1.857 Validation Lost 0.037 Validation Accuracy: 0.687
# Epoch: 1/15...  Train Loss: 1.505 Validation Lost 0.029 Validation Accuracy: 0.757
# Epoch: 1/15...  Train Loss: 1.559 Validation Lost 0.023 Validation Accuracy: 0.759
# Epoch: 1/15...  Train Loss: 1.531 Validation Lost 0.024 Validation Accuracy: 0.778
# Epoch: 1/15...  Train Loss: 1.370 Validation Lost 0.029 Validation Accuracy: 0.791
# Epoch: 1/15...  Train Loss: 1.296 Validation Lost 0.020 Validation Accuracy: 0.808
# Epoch: 1/15...  Train Loss: 1.500 Validation Lost 0.023 Validation Accuracy: 0.805
# Epoch: 1/15...  Train Loss: 1.157 Validation Lost 0.028 Validation Accuracy: 0.763
# Epoch: 1/15...  Train Loss: 1.281 Validation Lost 0.024 Validation Accuracy: 0.790
# Epoch: 1/15...  Train Loss: 1.273 Validation Lost 0.028 Validation Accuracy: 0.815
# Epoch: 1/15...  Train Loss: 1.181 Validation Lost 0.010 Validation Accuracy: 0.809
# Epoch: 2/15...  Train Loss: 0.357 Validation Lost 0.013 Validation Accuracy: 0.800
# Epoch: 2/15...  Train Loss: 1.026 Validation Lost 0.019 Validation Accuracy: 0.814
# Epoch: 2/15...  Train Loss: 0.879 Validation Lost 0.021 Validation Accuracy: 0.814
# Epoch: 2/15...  Train Loss: 0.954 Validation Lost 0.013 Validation Accuracy: 0.836
# Epoch: 2/15...  Train Loss: 1.106 Validation Lost 0.008 Validation Accuracy: 0.832
# Epoch: 2/15...  Train Loss: 0.938 Validation Lost 0.014 Validation Accuracy: 0.845
# Epoch: 2/15...  Train Loss: 0.875 Validation Lost 0.019 Validation Accuracy: 0.849
# Epoch: 2/15...  Train Loss: 0.801 Validation Lost 0.019 Validation Accuracy: 0.843
# Epoch: 2/15...  Train Loss: 1.114 Validation Lost 0.014 Validation Accuracy: 0.839
# Epoch: 2/15...  Train Loss: 0.880 Validation Lost 0.014 Validation Accuracy: 0.843
# Epoch: 2/15...  Train Loss: 0.866 Validation Lost 0.011 Validation Accuracy: 0.828
# Epoch: 2/15...  Train Loss: 0.920 Validation Lost 0.010 Validation Accuracy: 0.840
# Epoch: 2/15...  Train Loss: 0.877 Validation Lost 0.014 Validation Accuracy: 0.869
# Epoch: 2/15...  Train Loss: 0.942 Validation Lost 0.027 Validation Accuracy: 0.849
# Epoch: 2/15...  Train Loss: 0.781 Validation Lost 0.008 Validation Accuracy: 0.862
# Epoch: 2/15...  Train Loss: 0.818 Validation Lost 0.004 Validation Accuracy: 0.866
# Epoch: 2/15...  Train Loss: 0.891 Validation Lost 0.007 Validation Accuracy: 0.843
# Epoch: 2/15...  Train Loss: 0.924 Validation Lost 0.010 Validation Accuracy: 0.854
# Epoch: 2/15...  Train Loss: 0.870 Validation Lost 0.012 Validation Accuracy: 0.866
# Epoch: 2/15...  Train Loss: 0.903 Validation Lost 0.011 Validation Accuracy: 0.864
# Epoch: 3/15...  Train Loss: 0.624 Validation Lost 0.006 Validation Accuracy: 0.861
# Epoch: 3/15...  Train Loss: 0.790 Validation Lost 0.004 Validation Accuracy: 0.847
# Epoch: 3/15...  Train Loss: 0.743 Validation Lost 0.004 Validation Accuracy: 0.857
# Epoch: 3/15...  Train Loss: 0.682 Validation Lost 0.004 Validation Accuracy: 0.865
# Epoch: 3/15...  Train Loss: 0.708 Validation Lost 0.002 Validation Accuracy: 0.868
# Epoch: 3/15...  Train Loss: 0.764 Validation Lost 0.003 Validation Accuracy: 0.880
# Epoch: 3/15...  Train Loss: 0.714 Validation Lost 0.006 Validation Accuracy: 0.891
# Epoch: 3/15...  Train Loss: 0.738 Validation Lost 0.008 Validation Accuracy: 0.886
# Epoch: 3/15...  Train Loss: 0.630 Validation Lost 0.007 Validation Accuracy: 0.887
# Epoch: 3/15...  Train Loss: 0.723 Validation Lost 0.011 Validation Accuracy: 0.860
# Epoch: 3/15...  Train Loss: 0.679 Validation Lost 0.009 Validation Accuracy: 0.870
# Epoch: 3/15...  Train Loss: 0.746 Validation Lost 0.006 Validation Accuracy: 0.868
# Epoch: 3/15...  Train Loss: 0.573 Validation Lost 0.008 Validation Accuracy: 0.861
# Epoch: 3/15...  Train Loss: 0.680 Validation Lost 0.009 Validation Accuracy: 0.870
# Epoch: 3/15...  Train Loss: 0.882 Validation Lost 0.006 Validation Accuracy: 0.893
# Epoch: 3/15...  Train Loss: 0.695 Validation Lost 0.008 Validation Accuracy: 0.852
# Epoch: 3/15...  Train Loss: 0.838 Validation Lost 0.015 Validation Accuracy: 0.859
# Epoch: 3/15...  Train Loss: 0.755 Validation Lost 0.008 Validation Accuracy: 0.876
# Epoch: 3/15...  Train Loss: 0.652 Validation Lost 0.006 Validation Accuracy: 0.872
# Epoch: 3/15...  Train Loss: 0.704 Validation Lost 0.007 Validation Accuracy: 0.875
# Epoch: 4/15...  Train Loss: 0.111 Validation Lost 0.006 Validation Accuracy: 0.889
# Epoch: 4/15...  Train Loss: 0.680 Validation Lost 0.004 Validation Accuracy: 0.876
# Epoch: 4/15...  Train Loss: 0.689 Validation Lost 0.005 Validation Accuracy: 0.876
# Epoch: 4/15...  Train Loss: 0.650 Validation Lost 0.005 Validation Accuracy: 0.882
# Epoch: 4/15...  Train Loss: 0.633 Validation Lost 0.005 Validation Accuracy: 0.877
# Epoch: 4/15...  Train Loss: 0.562 Validation Lost 0.004 Validation Accuracy: 0.888
# Epoch: 4/15...  Train Loss: 0.596 Validation Lost 0.005 Validation Accuracy: 0.885
# Epoch: 4/15...  Train Loss: 0.654 Validation Lost 0.007 Validation Accuracy: 0.888
# Epoch: 4/15...  Train Loss: 0.606 Validation Lost 0.007 Validation Accuracy: 0.894
# Epoch: 4/15...  Train Loss: 0.552 Validation Lost 0.011 Validation Accuracy: 0.886
# Epoch: 4/15...  Train Loss: 0.650 Validation Lost 0.015 Validation Accuracy: 0.882
# Epoch: 4/15...  Train Loss: 0.640 Validation Lost 0.020 Validation Accuracy: 0.878
# Epoch: 4/15...  Train Loss: 0.750 Validation Lost 0.020 Validation Accuracy: 0.877
# Epoch: 4/15...  Train Loss: 0.653 Validation Lost 0.012 Validation Accuracy: 0.880
# Epoch: 4/15...  Train Loss: 0.860 Validation Lost 0.014 Validation Accuracy: 0.877
# Epoch: 4/15...  Train Loss: 0.681 Validation Lost 0.012 Validation Accuracy: 0.870
# Epoch: 4/15...  Train Loss: 0.729 Validation Lost 0.009 Validation Accuracy: 0.862
# Epoch: 4/15...  Train Loss: 0.689 Validation Lost 0.009 Validation Accuracy: 0.890
# Epoch: 4/15...  Train Loss: 0.591 Validation Lost 0.009 Validation Accuracy: 0.873
# Epoch: 4/15...  Train Loss: 0.769 Validation Lost 0.007 Validation Accuracy: 0.869
# Epoch: 4/15...  Train Loss: 0.621 Validation Lost 0.011 Validation Accuracy: 0.878
# Epoch: 5/15...  Train Loss: 0.406 Validation Lost 0.008 Validation Accuracy: 0.867
# Epoch: 5/15...  Train Loss: 0.868 Validation Lost 0.005 Validation Accuracy: 0.892
# Epoch: 5/15...  Train Loss: 0.546 Validation Lost 0.007 Validation Accuracy: 0.896
# Epoch: 5/15...  Train Loss: 0.641 Validation Lost 0.006 Validation Accuracy: 0.891
# Epoch: 5/15...  Train Loss: 0.609 Validation Lost 0.006 Validation Accuracy: 0.890
# Epoch: 5/15...  Train Loss: 0.579 Validation Lost 0.011 Validation Accuracy: 0.886
# Epoch: 5/15...  Train Loss: 0.589 Validation Lost 0.012 Validation Accuracy: 0.894
# Epoch: 5/15...  Train Loss: 0.563 Validation Lost 0.015 Validation Accuracy: 0.886
# Epoch: 5/15...  Train Loss: 0.529 Validation Lost 0.005 Validation Accuracy: 0.888
# Epoch: 5/15...  Train Loss: 0.674 Validation Lost 0.009 Validation Accuracy: 0.870
# Epoch: 5/15...  Train Loss: 0.548 Validation Lost 0.006 Validation Accuracy: 0.881
# Epoch: 5/15...  Train Loss: 0.579 Validation Lost 0.016 Validation Accuracy: 0.875
# Epoch: 5/15...  Train Loss: 0.768 Validation Lost 0.004 Validation Accuracy: 0.885
# Epoch: 5/15...  Train Loss: 0.562 Validation Lost 0.005 Validation Accuracy: 0.869
# Epoch: 5/15...  Train Loss: 0.535 Validation Lost 0.008 Validation Accuracy: 0.873
# Epoch: 5/15...  Train Loss: 0.536 Validation Lost 0.009 Validation Accuracy: 0.883
# Epoch: 5/15...  Train Loss: 0.587 Validation Lost 0.006 Validation Accuracy: 0.873
# Epoch: 5/15...  Train Loss: 0.990 Validation Lost 0.003 Validation Accuracy: 0.897
# Epoch: 5/15...  Train Loss: 0.637 Validation Lost 0.005 Validation Accuracy: 0.887
# Epoch: 5/15...  Train Loss: 0.668 Validation Lost 0.012 Validation Accuracy: 0.894
# Epoch: 6/15...  Train Loss: 0.524 Validation Lost 0.052 Validation Accuracy: 0.860
# Epoch: 6/15...  Train Loss: 0.505 Validation Lost 0.034 Validation Accuracy: 0.882
# Epoch: 6/15...  Train Loss: 0.500 Validation Lost 0.007 Validation Accuracy: 0.876
# Epoch: 6/15...  Train Loss: 0.607 Validation Lost 0.007 Validation Accuracy: 0.888
# Epoch: 6/15...  Train Loss: 0.620 Validation Lost 0.007 Validation Accuracy: 0.868
# Epoch: 6/15...  Train Loss: 0.474 Validation Lost 0.008 Validation Accuracy: 0.884
# Epoch: 6/15...  Train Loss: 0.619 Validation Lost 0.005 Validation Accuracy: 0.891
# Epoch: 6/15...  Train Loss: 0.600 Validation Lost 0.006 Validation Accuracy: 0.894
# Epoch: 6/15...  Train Loss: 0.492 Validation Lost 0.003 Validation Accuracy: 0.894
# Epoch: 6/15...  Train Loss: 0.512 Validation Lost 0.004 Validation Accuracy: 0.893
# Epoch: 6/15...  Train Loss: 0.553 Validation Lost 0.003 Validation Accuracy: 0.892
# Epoch: 6/15...  Train Loss: 0.608 Validation Lost 0.005 Validation Accuracy: 0.891
# Epoch: 6/15...  Train Loss: 0.491 Validation Lost 0.005 Validation Accuracy: 0.887
# Epoch: 6/15...  Train Loss: 0.670 Validation Lost 0.005 Validation Accuracy: 0.880
# Epoch: 6/15...  Train Loss: 0.529 Validation Lost 0.006 Validation Accuracy: 0.890
# Epoch: 6/15...  Train Loss: 0.526 Validation Lost 0.010 Validation Accuracy: 0.896
# Epoch: 6/15...  Train Loss: 0.608 Validation Lost 0.012 Validation Accuracy: 0.882
# Epoch: 6/15...  Train Loss: 0.561 Validation Lost 0.010 Validation Accuracy: 0.892
# Epoch: 6/15...  Train Loss: 0.522 Validation Lost 0.010 Validation Accuracy: 0.889
# Epoch: 6/15...  Train Loss: 0.616 Validation Lost 0.010 Validation Accuracy: 0.912
# Epoch: 7/15...  Train Loss: 0.127 Validation Lost 0.006 Validation Accuracy: 0.892
# Epoch: 7/15...  Train Loss: 0.623 Validation Lost 0.003 Validation Accuracy: 0.893
# Epoch: 7/15...  Train Loss: 0.610 Validation Lost 0.004 Validation Accuracy: 0.887
# Epoch: 7/15...  Train Loss: 0.665 Validation Lost 0.005 Validation Accuracy: 0.896
# Epoch: 7/15...  Train Loss: 0.568 Validation Lost 0.006 Validation Accuracy: 0.889
# Epoch: 7/15...  Train Loss: 0.507 Validation Lost 0.002 Validation Accuracy: 0.888
# Epoch: 7/15...  Train Loss: 0.482 Validation Lost 0.001 Validation Accuracy: 0.897
# Epoch: 7/15...  Train Loss: 0.552 Validation Lost 0.001 Validation Accuracy: 0.913
# Epoch: 7/15...  Train Loss: 0.626 Validation Lost 0.002 Validation Accuracy: 0.892
# Epoch: 7/15...  Train Loss: 0.597 Validation Lost 0.005 Validation Accuracy: 0.893
# Epoch: 7/15...  Train Loss: 0.524 Validation Lost 0.004 Validation Accuracy: 0.892
# Epoch: 7/15...  Train Loss: 0.584 Validation Lost 0.005 Validation Accuracy: 0.894
# Epoch: 7/15...  Train Loss: 0.474 Validation Lost 0.008 Validation Accuracy: 0.891
# Epoch: 7/15...  Train Loss: 0.581 Validation Lost 0.004 Validation Accuracy: 0.895
# Epoch: 7/15...  Train Loss: 0.506 Validation Lost 0.004 Validation Accuracy: 0.897
# Epoch: 7/15...  Train Loss: 0.548 Validation Lost 0.004 Validation Accuracy: 0.907
# Epoch: 7/15...  Train Loss: 0.494 Validation Lost 0.004 Validation Accuracy: 0.892
# Epoch: 7/15...  Train Loss: 0.462 Validation Lost 0.002 Validation Accuracy: 0.907
# Epoch: 7/15...  Train Loss: 0.444 Validation Lost 0.001 Validation Accuracy: 0.907
# Epoch: 7/15...  Train Loss: 0.583 Validation Lost 0.002 Validation Accuracy: 0.913
# Epoch: 7/15...  Train Loss: 0.484 Validation Lost 0.001 Validation Accuracy: 0.889
# Epoch: 8/15...  Train Loss: 0.431 Validation Lost 0.001 Validation Accuracy: 0.887
# Epoch: 8/15...  Train Loss: 0.406 Validation Lost 0.003 Validation Accuracy: 0.910
# Epoch: 8/15...  Train Loss: 0.415 Validation Lost 0.004 Validation Accuracy: 0.904
# Epoch: 8/15...  Train Loss: 0.576 Validation Lost 0.006 Validation Accuracy: 0.893
# Epoch: 8/15...  Train Loss: 0.488 Validation Lost 0.010 Validation Accuracy: 0.894
# Epoch: 8/15...  Train Loss: 0.462 Validation Lost 0.013 Validation Accuracy: 0.887
# Epoch: 8/15...  Train Loss: 0.465 Validation Lost 0.013 Validation Accuracy: 0.893
# Epoch: 8/15...  Train Loss: 0.492 Validation Lost 0.008 Validation Accuracy: 0.882
# Epoch: 8/15...  Train Loss: 0.677 Validation Lost 0.005 Validation Accuracy: 0.892
# Epoch: 8/15...  Train Loss: 0.494 Validation Lost 0.008 Validation Accuracy: 0.887
# Epoch: 8/15...  Train Loss: 0.546 Validation Lost 0.011 Validation Accuracy: 0.866
# Epoch: 8/15...  Train Loss: 0.501 Validation Lost 0.006 Validation Accuracy: 0.892
# Epoch: 8/15...  Train Loss: 0.679 Validation Lost 0.002 Validation Accuracy: 0.882
# Epoch: 8/15...  Train Loss: 0.658 Validation Lost 0.001 Validation Accuracy: 0.898
# Epoch: 8/15...  Train Loss: 0.568 Validation Lost 0.001 Validation Accuracy: 0.903
# Epoch: 8/15...  Train Loss: 0.529 Validation Lost 0.002 Validation Accuracy: 0.892
# Epoch: 8/15...  Train Loss: 0.546 Validation Lost 0.004 Validation Accuracy: 0.870
# Epoch: 8/15...  Train Loss: 0.508 Validation Lost 0.005 Validation Accuracy: 0.897
# Epoch: 8/15...  Train Loss: 0.570 Validation Lost 0.004 Validation Accuracy: 0.901
# Epoch: 9/15...  Train Loss: 0.133 Validation Lost 0.001 Validation Accuracy: 0.894
# Epoch: 9/15...  Train Loss: 0.465 Validation Lost 0.001 Validation Accuracy: 0.893
# Epoch: 9/15...  Train Loss: 0.410 Validation Lost 0.001 Validation Accuracy: 0.892
# Epoch: 9/15...  Train Loss: 0.638 Validation Lost 0.000 Validation Accuracy: 0.889
# Epoch: 9/15...  Train Loss: 0.549 Validation Lost 0.000 Validation Accuracy: 0.895
# Epoch: 9/15...  Train Loss: 0.476 Validation Lost 0.000 Validation Accuracy: 0.918
# Epoch: 9/15...  Train Loss: 0.353 Validation Lost 0.000 Validation Accuracy: 0.910
# Epoch: 9/15...  Train Loss: 0.536 Validation Lost 0.000 Validation Accuracy: 0.911
# Epoch: 9/15...  Train Loss: 0.499 Validation Lost 0.001 Validation Accuracy: 0.906
# Epoch: 9/15...  Train Loss: 0.469 Validation Lost 0.000 Validation Accuracy: 0.900
# Epoch: 9/15...  Train Loss: 0.529 Validation Lost 0.000 Validation Accuracy: 0.916
# Epoch: 9/15...  Train Loss: 0.496 Validation Lost 0.000 Validation Accuracy: 0.915
# Epoch: 9/15...  Train Loss: 0.624 Validation Lost 0.000 Validation Accuracy: 0.912
# Epoch: 9/15...  Train Loss: 0.622 Validation Lost 0.001 Validation Accuracy: 0.906
# Epoch: 9/15...  Train Loss: 0.358 Validation Lost 0.001 Validation Accuracy: 0.901
# Epoch: 9/15...  Train Loss: 0.454 Validation Lost 0.001 Validation Accuracy: 0.895
# Epoch: 9/15...  Train Loss: 0.417 Validation Lost 0.000 Validation Accuracy: 0.893
# Epoch: 9/15...  Train Loss: 0.440 Validation Lost 0.000 Validation Accuracy: 0.901
# Epoch: 9/15...  Train Loss: 0.453 Validation Lost 0.000 Validation Accuracy: 0.910
# Epoch: 9/15...  Train Loss: 0.374 Validation Lost 0.000 Validation Accuracy: 0.899
# Epoch: 9/15...  Train Loss: 0.436 Validation Lost 0.001 Validation Accuracy: 0.897
# Epoch: 10/15...  Train Loss: 0.334 Validation Lost 0.001 Validation Accuracy: 0.899
# Epoch: 10/15...  Train Loss: 0.453 Validation Lost 0.000 Validation Accuracy: 0.911
# Epoch: 10/15...  Train Loss: 0.560 Validation Lost 0.001 Validation Accuracy: 0.910
# Epoch: 10/15...  Train Loss: 0.392 Validation Lost 0.001 Validation Accuracy: 0.910
# Epoch: 10/15...  Train Loss: 0.452 Validation Lost 0.001 Validation Accuracy: 0.903
# Epoch: 10/15...  Train Loss: 0.648 Validation Lost 0.002 Validation Accuracy: 0.901
# Epoch: 10/15...  Train Loss: 0.549 Validation Lost 0.004 Validation Accuracy: 0.893
# Epoch: 10/15...  Train Loss: 0.435 Validation Lost 0.010 Validation Accuracy: 0.897
# Epoch: 10/15...  Train Loss: 0.591 Validation Lost 0.002 Validation Accuracy: 0.898
# Epoch: 10/15...  Train Loss: 0.475 Validation Lost 0.001 Validation Accuracy: 0.905
# Epoch: 10/15...  Train Loss: 0.490 Validation Lost 0.001 Validation Accuracy: 0.905
# Epoch: 10/15...  Train Loss: 0.551 Validation Lost 0.007 Validation Accuracy: 0.896
# Epoch: 10/15...  Train Loss: 0.444 Validation Lost 0.007 Validation Accuracy: 0.908
# Epoch: 10/15...  Train Loss: 0.532 Validation Lost 0.003 Validation Accuracy: 0.904
# Epoch: 10/15...  Train Loss: 0.389 Validation Lost 0.001 Validation Accuracy: 0.897
# Epoch: 10/15...  Train Loss: 0.387 Validation Lost 0.001 Validation Accuracy: 0.892
# Epoch: 10/15...  Train Loss: 0.419 Validation Lost 0.003 Validation Accuracy: 0.896
# Epoch: 10/15...  Train Loss: 0.504 Validation Lost 0.002 Validation Accuracy: 0.919
# Epoch: 10/15...  Train Loss: 0.484 Validation Lost 0.001 Validation Accuracy: 0.910
# Epoch: 10/15...  Train Loss: 0.483 Validation Lost 0.001 Validation Accuracy: 0.906
# Epoch: 10/15...  Train Loss: 0.536 Validation Lost 0.001 Validation Accuracy: 0.906
# Epoch: 11/15...  Train Loss: 0.348 Validation Lost 0.005 Validation Accuracy: 0.911
# Epoch: 11/15...  Train Loss: 0.560 Validation Lost 0.007 Validation Accuracy: 0.908
# Epoch: 11/15...  Train Loss: 0.451 Validation Lost 0.001 Validation Accuracy: 0.903
# Epoch: 11/15...  Train Loss: 0.391 Validation Lost 0.000 Validation Accuracy: 0.894
# Epoch: 11/15...  Train Loss: 0.641 Validation Lost 0.000 Validation Accuracy: 0.906
# Epoch: 11/15...  Train Loss: 0.536 Validation Lost 0.000 Validation Accuracy: 0.904
# Epoch: 11/15...  Train Loss: 0.538 Validation Lost 0.001 Validation Accuracy: 0.898
# Epoch: 11/15...  Train Loss: 0.441 Validation Lost 0.002 Validation Accuracy: 0.894
# Epoch: 11/15...  Train Loss: 0.440 Validation Lost 0.003 Validation Accuracy: 0.904
# Epoch: 11/15...  Train Loss: 0.553 Validation Lost 0.004 Validation Accuracy: 0.905
# Epoch: 11/15...  Train Loss: 0.537 Validation Lost 0.005 Validation Accuracy: 0.897
# Epoch: 11/15...  Train Loss: 0.540 Validation Lost 0.004 Validation Accuracy: 0.894
# Epoch: 11/15...  Train Loss: 0.519 Validation Lost 0.005 Validation Accuracy: 0.886
# Epoch: 11/15...  Train Loss: 0.448 Validation Lost 0.002 Validation Accuracy: 0.893
# Epoch: 11/15...  Train Loss: 0.474 Validation Lost 0.000 Validation Accuracy: 0.904
# Epoch: 11/15...  Train Loss: 0.485 Validation Lost 0.000 Validation Accuracy: 0.899
# Epoch: 11/15...  Train Loss: 0.474 Validation Lost 0.000 Validation Accuracy: 0.905
# Epoch: 11/15...  Train Loss: 0.452 Validation Lost 0.000 Validation Accuracy: 0.906
# Epoch: 11/15...  Train Loss: 0.606 Validation Lost 0.001 Validation Accuracy: 0.887
# Epoch: 11/15...  Train Loss: 0.597 Validation Lost 0.001 Validation Accuracy: 0.905
# Epoch: 12/15...  Train Loss: 0.209 Validation Lost 0.001 Validation Accuracy: 0.911
# Epoch: 12/15...  Train Loss: 0.412 Validation Lost 0.001 Validation Accuracy: 0.910
# Epoch: 12/15...  Train Loss: 0.440 Validation Lost 0.002 Validation Accuracy: 0.905
# Epoch: 12/15...  Train Loss: 0.460 Validation Lost 0.006 Validation Accuracy: 0.908
# Epoch: 12/15...  Train Loss: 0.466 Validation Lost 0.006 Validation Accuracy: 0.907
# Epoch: 12/15...  Train Loss: 0.455 Validation Lost 0.002 Validation Accuracy: 0.897
# Epoch: 12/15...  Train Loss: 0.415 Validation Lost 0.001 Validation Accuracy: 0.901
# Epoch: 12/15...  Train Loss: 0.522 Validation Lost 0.001 Validation Accuracy: 0.898
# Epoch: 12/15...  Train Loss: 0.500 Validation Lost 0.002 Validation Accuracy: 0.899
# Epoch: 12/15...  Train Loss: 0.489 Validation Lost 0.002 Validation Accuracy: 0.903
# Epoch: 12/15...  Train Loss: 0.492 Validation Lost 0.003 Validation Accuracy: 0.891
# Epoch: 12/15...  Train Loss: 0.457 Validation Lost 0.004 Validation Accuracy: 0.905
# Epoch: 12/15...  Train Loss: 0.348 Validation Lost 0.002 Validation Accuracy: 0.910
# Epoch: 12/15...  Train Loss: 0.526 Validation Lost 0.001 Validation Accuracy: 0.905
# Epoch: 12/15...  Train Loss: 0.484 Validation Lost 0.001 Validation Accuracy: 0.906
# Epoch: 12/15...  Train Loss: 0.562 Validation Lost 0.001 Validation Accuracy: 0.915
# Epoch: 12/15...  Train Loss: 0.453 Validation Lost 0.001 Validation Accuracy: 0.894
# Epoch: 12/15...  Train Loss: 0.434 Validation Lost 0.002 Validation Accuracy: 0.888
# Epoch: 12/15...  Train Loss: 0.511 Validation Lost 0.002 Validation Accuracy: 0.886
# Epoch: 12/15...  Train Loss: 0.541 Validation Lost 0.001 Validation Accuracy: 0.903
# Epoch: 13/15...  Train Loss: 0.300 Validation Lost 0.000 Validation Accuracy: 0.895
# Epoch: 13/15...  Train Loss: 0.445 Validation Lost 0.001 Validation Accuracy: 0.907
# Epoch: 13/15...  Train Loss: 0.465 Validation Lost 0.002 Validation Accuracy: 0.898
# Epoch: 13/15...  Train Loss: 0.559 Validation Lost 0.006 Validation Accuracy: 0.894
# Epoch: 13/15...  Train Loss: 0.447 Validation Lost 0.005 Validation Accuracy: 0.898
# Epoch: 13/15...  Train Loss: 0.394 Validation Lost 0.006 Validation Accuracy: 0.898
# Epoch: 13/15...  Train Loss: 0.438 Validation Lost 0.011 Validation Accuracy: 0.898
# Epoch: 13/15...  Train Loss: 0.545 Validation Lost 0.021 Validation Accuracy: 0.895
# Epoch: 13/15...  Train Loss: 0.455 Validation Lost 0.019 Validation Accuracy: 0.894
# Epoch: 13/15...  Train Loss: 0.385 Validation Lost 0.001 Validation Accuracy: 0.898
# Epoch: 13/15...  Train Loss: 0.488 Validation Lost 0.000 Validation Accuracy: 0.903
# Epoch: 13/15...  Train Loss: 0.438 Validation Lost 0.001 Validation Accuracy: 0.897
# Epoch: 13/15...  Train Loss: 0.421 Validation Lost 0.001 Validation Accuracy: 0.888
# Epoch: 13/15...  Train Loss: 0.680 Validation Lost 0.004 Validation Accuracy: 0.898
# Epoch: 13/15...  Train Loss: 0.433 Validation Lost 0.011 Validation Accuracy: 0.897
# Epoch: 13/15...  Train Loss: 0.489 Validation Lost 0.010 Validation Accuracy: 0.903
# Epoch: 13/15...  Train Loss: 0.339 Validation Lost 0.013 Validation Accuracy: 0.913
# Epoch: 13/15...  Train Loss: 0.471 Validation Lost 0.015 Validation Accuracy: 0.903
# Epoch: 13/15...  Train Loss: 0.497 Validation Lost 0.006 Validation Accuracy: 0.913
# Epoch: 14/15...  Train Loss: 0.059 Validation Lost 0.002 Validation Accuracy: 0.903
# Epoch: 14/15...  Train Loss: 0.467 Validation Lost 0.002 Validation Accuracy: 0.903
# Epoch: 14/15...  Train Loss: 0.444 Validation Lost 0.002 Validation Accuracy: 0.901
# Epoch: 14/15...  Train Loss: 0.402 Validation Lost 0.001 Validation Accuracy: 0.903
# Epoch: 14/15...  Train Loss: 0.467 Validation Lost 0.002 Validation Accuracy: 0.911
# Epoch: 14/15...  Train Loss: 0.449 Validation Lost 0.004 Validation Accuracy: 0.904
# Epoch: 14/15...  Train Loss: 0.478 Validation Lost 0.001 Validation Accuracy: 0.900
# Epoch: 14/15...  Train Loss: 0.482 Validation Lost 0.000 Validation Accuracy: 0.893
# Epoch: 14/15...  Train Loss: 0.399 Validation Lost 0.000 Validation Accuracy: 0.901
# Epoch: 14/15...  Train Loss: 0.428 Validation Lost 0.000 Validation Accuracy: 0.906
# Epoch: 14/15...  Train Loss: 0.461 Validation Lost 0.000 Validation Accuracy: 0.911
# Epoch: 14/15...  Train Loss: 0.609 Validation Lost 0.000 Validation Accuracy: 0.911
# Epoch: 14/15...  Train Loss: 0.418 Validation Lost 0.000 Validation Accuracy: 0.912
# Epoch: 14/15...  Train Loss: 0.366 Validation Lost 0.001 Validation Accuracy: 0.904
# Epoch: 14/15...  Train Loss: 0.473 Validation Lost 0.001 Validation Accuracy: 0.900
# Epoch: 14/15...  Train Loss: 0.433 Validation Lost 0.001 Validation Accuracy: 0.903
# Epoch: 14/15...  Train Loss: 0.438 Validation Lost 0.002 Validation Accuracy: 0.911
# Epoch: 14/15...  Train Loss: 0.513 Validation Lost 0.001 Validation Accuracy: 0.910
# Epoch: 14/15...  Train Loss: 0.539 Validation Lost 0.001 Validation Accuracy: 0.910
# Epoch: 14/15...  Train Loss: 0.446 Validation Lost 0.001 Validation Accuracy: 0.906
# Epoch: 14/15...  Train Loss: 0.453 Validation Lost 0.002 Validation Accuracy: 0.903
# Epoch: 15/15...  Train Loss: 0.279 Validation Lost 0.003 Validation Accuracy: 0.907
# Epoch: 15/15...  Train Loss: 0.377 Validation Lost 0.004 Validation Accuracy: 0.893
# Epoch: 15/15...  Train Loss: 0.484 Validation Lost 0.001 Validation Accuracy: 0.907
# Epoch: 15/15...  Train Loss: 0.495 Validation Lost 0.001 Validation Accuracy: 0.903
# Epoch: 15/15...  Train Loss: 0.450 Validation Lost 0.003 Validation Accuracy: 0.913
# Epoch: 15/15...  Train Loss: 0.455 Validation Lost 0.003 Validation Accuracy: 0.910
# Epoch: 15/15...  Train Loss: 0.497 Validation Lost 0.003 Validation Accuracy: 0.919
# Epoch: 15/15...  Train Loss: 0.473 Validation Lost 0.001 Validation Accuracy: 0.916
# Epoch: 15/15...  Train Loss: 0.552 Validation Lost 0.001 Validation Accuracy: 0.905
# Epoch: 15/15...  Train Loss: 0.412 Validation Lost 0.000 Validation Accuracy: 0.894
# Epoch: 15/15...  Train Loss: 0.553 Validation Lost 0.001 Validation Accuracy: 0.899
# Epoch: 15/15...  Train Loss: 0.457 Validation Lost 0.002 Validation Accuracy: 0.903
# Epoch: 15/15...  Train Loss: 0.521 Validation Lost 0.002 Validation Accuracy: 0.912
# Epoch: 15/15...  Train Loss: 0.394 Validation Lost 0.001 Validation Accuracy: 0.912
# Epoch: 15/15...  Train Loss: 0.412 Validation Lost 0.002 Validation Accuracy: 0.911
# Epoch: 15/15...  Train Loss: 0.547 Validation Lost 0.001 Validation Accuracy: 0.910
# Epoch: 15/15...  Train Loss: 0.519 Validation Lost 0.001 Validation Accuracy: 0.892
# Epoch: 15/15...  Train Loss: 0.404 Validation Lost 0.001 Validation Accuracy: 0.899
# Epoch: 15/15...  Train Loss: 0.471 Validation Lost 0.000 Validation Accuracy: 0.905
# Epoch: 15/15...  Train Loss: 0.488 Validation Lost 0.000 Validation Accuracy: 0.909
# Epoch: 15/15...  Train Loss: 0.452 Validation Lost 0.000 Validation Accuracy: 0.911

# %% [markdown]
# ## Testing your network
#
# It's good practice to test your trained network on test data, images the network has never seen either in training or validation. This will give you a good estimate for the model's performance on completely new images. Run the test images through the network and measure the accuracy, the same way you did validation. You should be able to reach around 70% accuracy on the test set if the model has been trained well.

# %%
# TODO: Do validation on the test set
correct = 0
total = 0
model.to(device)


with torch.no_grad():
    for data in testloader:
        images, labels = data
        images, labels = images.to(device), labels.to(device)
        # Get probabilities
        outputs = model(images)
        # Turn probabilities into predictions
        _, predicted_outcome = torch.max(outputs.data, 1)
        # Total number of images
        total += labels.size(0)
        # Count number of cases in which predictions are correct
        correct += (predicted_outcome == labels).sum().item()

print(f"Test accuracy of model: {round(100 * correct / total,3)}%")
# Out:
# Test accuracy of model: 88.767%

# %% [markdown]
# ## Save the checkpoint
#
# Now that your network is trained, save the model so you can load it later for making predictions. You probably want to save other things such as the mapping of classes to indices which you get from one of the image datasets: `image_datasets['train'].class_to_idx`. You can attach this to the model as an attribute which makes inference easier later on.
#
# ```model.class_to_idx = image_datasets['train'].class_to_idx```
#
# Remember that you'll want to completely rebuild the model later so you can use it for inference. Make sure to include any information you need in the checkpoint. If you want to load the model and keep training, you'll want to save the number of epochs as well as the optimizer state, `optimizer.state_dict`. You'll likely want to use this trained model in the next part of the project, so best to save it now.

# %%
# TODO: Save the checkpoint 
model.class_to_idx = train_data.class_to_idx
model.cpu
torch.save({'model' :'vgg16',
            'classifier': model.classifier,
            'num_epochs': epochs,
            'hidden_layer1':600,
            'state_dict':model.state_dict(), #A state_dict is simply a Python dictionary object that maps each layer to its parameter tensor. 
            'class_to_idx':model.class_to_idx},
            'checkpoint.pth')

# %% [markdown]
# ## Loading the checkpoint
#
# At this point it's good to write a function that can load a checkpoint and rebuild the model. That way you can come back to this project and keep working on it without having to retrain the network.

# %%
# TODO: Write a function that loads a checkpoint and rebuilds the model
def load_checkpoint(filepath):
    
    # Checkpoint for when using GPU
    checkpoint = torch.load('checkpoint.pth')
    if checkpoint['model']=='vgg16':
        model = models.vgg16(pretrained=True)
        for param in model.parameters():
            param.requires_grad = False
    else: 
        print ("Model not recognized")

    # Checkpoint for when using CPU
    #checkpoint = torch.load(filepath, map_location=lambda storage, loc: storage)
    
    model.classifier = checkpoint['classifier'] 
    model.class_to_idx = checkpoint['class_to_idx']
    model.load_state_dict(checkpoint['state_dict'])

    
    return model

# %%
model = load_checkpoint('checkpoint.pth')
# Out:
# Downloading: "https://download.pytorch.org/models/vgg16-397923af.pth" to /root/.torch/models/vgg16-397923af.pth
# 100%|██████████| 553433881/553433881 [00:05<00:00, 104282766.74it/s]

# %% [markdown]
# # Inference for classification
#
# Now you'll write a function to use a trained network for inference. That is, you'll pass an image into the network and predict the class of the flower in the image. Write a function called `predict` that takes an image and a model, then returns the top $K$ most likely classes along with the probabilities. It should look like
#
# ```python
# probs, classes = predict(image_path, model)
# print(probs)
# print(classes)
# > [ 0.01558163  0.01541934  0.01452626  0.01443549  0.01407339]
# > ['70', '3', '45', '62', '55']
# ```
#
# First you'll need to handle processing the input image such that it can be used in your network.
#
# ## Image Preprocessing
#
# You'll want to use `PIL` to load the image ([documentation](https://pillow.readthedocs.io/en/latest/reference/Image.html)). It's best to write a function that preprocesses the image so it can be used as input for the model. This function should process the images in the same manner used for training.
#
# First, resize the images where the shortest side is 256 pixels, keeping the aspect ratio. This can be done with the [`thumbnail`](http://pillow.readthedocs.io/en/3.1.x/reference/Image.html#PIL.Image.Image.thumbnail) or [`resize`](http://pillow.readthedocs.io/en/3.1.x/reference/Image.html#PIL.Image.Image.thumbnail) methods. Then you'll need to crop out the center 224x224 portion of the image.
#
# Color channels of images are typically encoded as integers 0-255, but the model expected floats 0-1. You'll need to convert the values. It's easiest with a Numpy array, which you can get from a PIL image like so `np_image = np.array(pil_image)`.
#
# As before, the network expects the images to be normalized in a specific way. For the means, it's `[0.485, 0.456, 0.406]` and for the standard deviations `[0.229, 0.224, 0.225]`. You'll want to subtract the means from each color channel, then divide by the standard deviation.
#
# And finally, PyTorch expects the color channel to be the first dimension but it's the third dimension in the PIL image and Numpy array. You can reorder dimensions using [`ndarray.transpose`](https://docs.scipy.org/doc/numpy-1.13.0/reference/generated/numpy.ndarray.transpose.html). The color channel needs to be first and retain the order of the other two dimensions.

# %%
def process_image(image):
    ''' Scales, crops, and normalizes a PIL image for a PyTorch model,
        returns an Numpy array
    '''
    img = Image.open(image)
   
    image_transform = transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
    ])
    
    img_tens = image_transform(img)
    
    return img_tens
    # TODO: Process a PIL image for use in a PyTorch model
image = process_image("flowers/test/1/image_06743.jpg")

# %%
image.shape
# Out:
# torch.Size([3, 224, 224])

# %% [markdown]
# To check your work, the function below converts a PyTorch tensor and displays it in the notebook. If your `process_image` function works, running the output through this function should return the original image (except for the cropped out portions).

# %%
def imshow(image, ax=None, title=None):
    """Imshow for Tensor."""
    if ax is None:
        fig, ax = plt.subplots()
    
    # PyTorch tensors assume the color channel is the first dimension
    # but matplotlib assumes is the third dimension
    image = image.numpy().transpose((1, 2, 0))
    
    # Undo preprocessing
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    image = std * image + mean
    
    # Image needs to be clipped between 0 and 1 or it looks like noise when displayed
    image = np.clip(image, 0, 1)
    
    ax.imshow(image)
    
    return ax

# %%
imshow(image)

# %% [markdown]
# ## Class Prediction
#
# Once you can get images in the correct format, it's time to write a function for making predictions with your model. A common practice is to predict the top 5 or so (usually called top-$K$) most probable classes. You'll want to calculate the class probabilities then find the $K$ largest values.
#
# To get the top $K$ largest values in a tensor use [`x.topk(k)`](http://pytorch.org/docs/master/torch.html#torch.topk). This method returns both the highest `k` probabilities and the indices of those probabilities corresponding to the classes. You need to convert from these indices to the actual class labels using `class_to_idx` which hopefully you added to the model or from an `ImageFolder` you used to load the data ([see here](#Save-the-checkpoint)). Make sure to invert the dictionary so you get a mapping from index to class as well.
#
# Again, this method should take a path to an image and a model checkpoint, then return the probabilities and classes.
#
# ```python
# probs, classes = predict(image_path, model)
# print(probs)
# print(classes)
# > [ 0.01558163  0.01541934  0.01452626  0.01443549  0.01407339]
# > ['70', '3', '45', '62', '55']
# ```

# %%
def predict(image_path, model_path, topk=5):
    ''' Predict the class (or classes) of an image using a trained deep learning model.
    '''
    model.to(device)
    img_torch = process_image(image_path)
    img_torch = img_torch.unsqueeze_(0)
    img_torch = img_torch.float()
    
    with torch.no_grad():
        output = model.forward(img_torch.cuda())
        
    probability = F.softmax(output.data,dim=1)
    
    return probability.topk(topk)
    # TODO: Implement the code to predict the class from an image file

# %% [markdown]
# ## Sanity Checking
#
# Now that you can use a trained model for predictions, check to make sure it makes sense. Even if the testing accuracy is high, it's always good to check that there aren't obvious bugs. Use `matplotlib` to plot the probabilities for the top 5 classes as a bar graph, along with the input image. It should look like this:
#
# <img src='assets/inference_example.png' width=300px>
#
# You can convert from the class integer encoding to actual flower names with the `cat_to_name.json` file (should have been loaded earlier in the notebook). To show a PyTorch tensor as an image, use the `imshow` function defined above.

# %%
# TODO: Display an image along with the top 5 classes
model_path = 'checkpoint.pth'
image_path = data_dir + '/test' + '/10/' + 'image_07090'

# Other images to try:
# image_path = data_dir + '/test' + '/1/' + 'image_06073'


# Getting prediction
probs,classes = predict(image_path+'.jpg', model_path, topk=5)

# Uncomment to check if the class of flower (as seen from the file path) matches the top one predicted:
print(classes[0])

# Converting classes to names
names = []
classes = classes.tolist()
for i in classes[0]:
    names += [cat_to_name[str(i)]]

# Creating PIL image
image = Image.open(image_path+'.jpg')

# Plotting test image and predicted probabilites
f, ax = plt.subplots(2,figsize = (6,10))

ax[0].imshow(image)
ax[0].set_title(names[0])

y_names = np.arange(len(names))
ax[1].barh(y_names, probs.tolist()[0], color='darkblue')
ax[1].set_yticks(y_names)
ax[1].set_yticklabels(names)
ax[1].invert_yaxis() 

plt.show()
# Out:
# tensor([  1,  24,   8,  48,  27], device='cuda:0')

# %%
print (classes)
# Out:
# [[1, 24, 8, 48, 27]]

# %% [markdown]
# ### References:
# Udacity Deep Learning Courses
#
# Detailed tutorial on image classification project
# https://medium.com/@josh_2774/deep-learning-with-pytorch-9574e74d17ad
#
# Transfer learning tutorial - documentation
# https://pytorch.org/tutorials/beginner/transfer_learning_tutorial.html#load-data
#
# Saving and loading models documentation:
# https://pytorch.org/tutorials/beginner/saving_loading_models.html?highlight=model%20state_dict
#
# Image Module:
# https://pillow.readthedocs.io/en/latest/reference/Image.html
#
# Aggparser documentation:
# https://docs.python.org/3/library/argparse.html
#
# Saving and loading model:
# https://pytorch.org/tutorials/beginner/saving_loading_models.html#saving-loading-model-for-inference
